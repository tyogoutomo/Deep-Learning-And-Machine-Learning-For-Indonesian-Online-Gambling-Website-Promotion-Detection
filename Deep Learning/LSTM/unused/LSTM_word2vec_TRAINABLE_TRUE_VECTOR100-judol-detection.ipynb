# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

import torch
import pandas as pd
from transformers import BertTokenizer, BertModel,BertForSequenceClassification
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from gensim.models import Word2Vec

# %pip install Sastrawi
# !unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

label_type = ['NotPromotion', 'Promotion']
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 2025-05-03 14:59:22.898799: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746284363.102131      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746284363.157536      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.5 MB/s eta 0:00:0000:01
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Note: you may need to restart the kernel to use updated packages.
# Archive:  /usr/share/nltk_data/corpora/wordnet.zip
#    creating: /usr/share/nltk_data/corpora/wordnet/
#   inflating: /usr/share/nltk_data/corpora/wordnet/lexnames
#   inflating: /usr/share/nltk_data/corpora/wordnet/data.verb
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.adv
#   inflating: /usr/share/nltk_data/corpora/wordnet/adv.exc
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.verb
#   inflating: /usr/share/nltk_data/corpora/wordnet/cntlist.rev
#   inflating: /usr/share/nltk_data/corpora/wordnet/data.adj
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.adj
#   inflating: /usr/share/nltk_data/corpora/wordnet/LICENSE
#   inflating: /usr/share/nltk_data/corpora/wordnet/citation.bib
#   inflating: /usr/share/nltk_data/corpora/wordnet/noun.exc
#   inflating: /usr/share/nltk_data/corpora/wordnet/verb.exc
#   inflating: /usr/share/nltk_data/corpora/wordnet/README
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.sense
#   inflating: /usr/share/nltk_data/corpora/wordnet/data.noun
#   inflating: /usr/share/nltk_data/corpora/wordnet/data.adv
#   inflating: /usr/share/nltk_data/corpora/wordnet/index.noun
#   inflating: /usr/share/nltk_data/corpora/wordnet/adj.exc

# %%
# %load_ext cudf.pandas

# %pip install seaborn
# %pip install Sastrawi
# %pip install wordcloud
# %pip install torch
# %pip install transformers
# %pip install nltk
# %pip install tensorflow
# %pip install gensim --upgrade
# %pip install Sastrawi
# !unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/

# %%
combined_data = pd.read_csv('/kaggle/input/dataset-scraping-sendiri/dataset_combined_new - dataset_combined_new.csv', sep=',')
training_data = pd.read_csv('/kaggle/input/dataset-scraping-sendiri/train.csv', sep=',').dropna()
testing_data = pd.read_csv('/kaggle/input/dataset-scraping-sendiri/test.csv', sep=',').dropna()
validation_data = pd.read_csv('/kaggle/input/dataset-scraping-sendiri/val.csv').dropna()

# training_data = training_data.sample(frac = 1)
training_data.head()
# Out:
#                                                 text  label
# 0  Mencari pengalaman daring yang lancar? AERO88 ...      1
# 1  Itu kayanya di kasih tanda deh yg bisa di lewa...      0
# 2  Whatsapp Telegram Livechat Daftar Login Hdtoto...      1
# 3                                  KO SELASA SI BABG      0
# 4  TERLEPAS DARI GAME NYA YANG BAGUS, SEMOGA BANG...      0

# %%
print("train isna:",training_data['text'].isna().sum())
print("test isna:",testing_data['text'].isna().sum())
print("val isna:",validation_data['text'].isna().sum())

print(training_data[training_data['text'].isna()][['text', 'label']])
# Out:
# train isna: 0
# test isna: 0
# val isna: 0
# Empty DataFrame
# Columns: [text, label]
# Index: []

# %% [markdown]
# # Preprocessing

# %%
stop_factory = StopWordRemoverFactory()
stopwords = stop_factory.get_stop_words()
custom_stopwords = ['aku', 'yg', 'kamu']
drop_stopwords = ['pula', 'pasti', 'amat', 'ingin', 'sampai']

stopwords += custom_stopwords
stopwords = [word for word in stopwords if word not in drop_stopwords]

pattern = r"[^A-Za-z ]"

print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'apalagi', 'bagaimanapun', 'aku', 'yg', 'kamu']

# %%
def preprocess_text(texts):
    sentences=[]
    for index, text in enumerate(texts):

        word_list = word_tokenize(text)
        word_list = [word for word in word_list if word not in stopwords]
        
        text = ' '.join(word_list)
        texts[index] = text
        sentences.append(word_list)
    return texts, sentences

# %%
texts_raw_train = training_data['text'].values.copy()
texts_raw_val = validation_data['text'].values.copy()
texts_raw_test = testing_data['text'].values.copy()
y_train = training_data['label'].values.copy()
y_val = validation_data['label'].values.copy()
y_test = testing_data['label'].values.copy()

# %%
texts_train,sentences = preprocess_text(texts_raw_train)
texts_val,_ = preprocess_text(texts_raw_val)
texts_test,_ = preprocess_text(texts_raw_test)

texts_train
# Out:
# array(['Mencari pengalaman daring lancar ? AERO88 mungkin solusinya .',
#        'Itu kayanya kasih tanda deh lewatin apa ngga , contohnya kerucut+tong sampah biru',
#        'Whatsapp Telegram Livechat Daftar Login Hdtoto Beranda Slot Online Live Casino Sportsbook Arcade Togel Poker slider Jackpot Daily Wins Gates of Olympus Bonanza Gold < Starlight Princess Sweet power thor megaways Treasure Wild Aztec Gems Gatot Kaca Popular Games bowl Mahjong Ways Break Away Lucky Wilds Koi Gate 1000 Wishes Gem Saviour Conquest Chronicles X Up Gold Blitz Elven Roma Silverback Multiplier Mountain Fiery Sevens Hot Phoenix Rises Neko Fortune Tiger garuda Treasures Bandito fireworks Dreams Macau Rooster Rumble > Platform Hiburan Terbaru No.1 Indonesia Penyedia pragmatic pgsoft habanero cq9 spadegaming ttg joker microgaming ion sexy gaming allbet idnlive saba sports Metode Pembayaran Transfer Bank Pulsa E-Money ©2024 Hdtoto . All rights reserved | 18+',
#        ..., 'Kerennn',
#        'Saya merekomendasikan ρułau777 siapa mencari tempat terpercaya .',
#        'GG bangeng'], dtype=object)

# %%
print(len(sentences))
# Out:
# 2736

# %% [markdown]
# # Tokenization & Vectorizer

# %%
# Define parameters

EMBEDDING_DIM = 100
MAX_LEN = 128

# %% [markdown]
# ## Torch Tokenization

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts_train)

train_texts_seq = tokenizer.texts_to_sequences(texts_train)
val_texts_seq = tokenizer.texts_to_sequences(texts_val)
test_texts_seq = tokenizer.texts_to_sequences(texts_test)

train_texts_padded = pad_sequences(train_texts_seq, maxlen=MAX_LEN, padding='post', truncating='post')
val_texts_padded = pad_sequences(val_texts_seq, maxlen=MAX_LEN, padding='post', truncating='post')
test_texts_padded = pad_sequences(test_texts_seq, maxlen=MAX_LEN, padding='post', truncating='post')

# %%
train_texts_padded.shape
# Out:
# (2736, 128)

# %% [markdown]
# ## Word2Vec Vectorizer

# %%
w2v_model = Word2Vec(sentences, vector_size=EMBEDDING_DIM, window=5, min_count=1, workers=4)
embedding_words = list(w2v_model.wv.key_to_index)

# %%
w2v_model.wv.most_similar('untung')
# Out:
# [('Semua', 0.7167677283287048),
#  ('member', 0.715676486492157),
#  ('bg', 0.7088295817375183),
#  ('mulai', 0.7053470611572266),
#  (')', 0.7033091187477112),
#  ('juta', 0.7013475894927979),
#  ('%', 0.70100337266922),
#  ('kemenangan', 0.700989305973053),
#  ('hari', 0.7009550333023071),
#  ('selalu', 0.7007797956466675)]

# %%
w2v_model.vector_size
# Out:
# 100

# %%
# def vectorize_texts(texts, model):
#     vectors = []
#     for text in texts:
#         tokens = text.split()
#         token_vectors = [model.wv[token] for token in tokens if token in model.wv]
#         if token_vectors:
#             text_vector = np.mean(token_vectors, axis=0)  # Average the token vectors
#         else:
#             text_vector = np.zeros(model.vector_size)  # Fallback for empty texts
#         vectors.append(text_vector)
#     return np.array(vectors)

# w2v_embedding = vectorize_texts(texts_train, w2v_model)

# %%
VOCAB_SIZE = len(tokenizer.word_index) + 1
VOCAB_SIZE
# Out:
# 11021

# %%
embedding_matrix = np.zeros((VOCAB_SIZE, EMBEDDING_DIM))
for word, i in tokenizer.word_index.items():
    if word in w2v_model.wv:
        embedding_matrix[i] = w2v_model.wv[word]
    else:
        embedding_matrix[i] = np.zeros(EMBEDDING_DIM)

# %%
# Print some statistics first to understand the vocabulary coverage
vocab_size = len(tokenizer.word_index)
w2v_vocab_size = len(w2v_model.wv.key_to_index)
missing_count = 0

embedding_matrix = np.zeros((VOCAB_SIZE, EMBEDDING_DIM))
for word, i in tokenizer.word_index.items():
    if word in w2v_model.wv:
        embedding_matrix[i] = w2v_model.wv[word]
    else:
        missing_count += 1
        print(i, end=" ")
        # Initialize missing words with random small numbers instead of zeros
        embedding_matrix[i] = np.random.uniform(-0.25, 0.25, EMBEDDING_DIM)

print(f"Total words in tokenizer: {vocab_size}")
print(f"Total words in Word2Vec: {w2v_vocab_size}")
print(f"Words not found in Word2Vec: {missing_count} ({(missing_count/vocab_size*100):.2f}%)")
# Out:
607 2609 2614 2617 2618 2619 2622 2625 2626 2627 2628 2631 2635 2643 2646 2649 2652 2653 2654 2655 2658 2659 2660 2661 2664 2668 2675 2679 2688 2699 2700 2701 2702 2710 2715 2720 2721 2724 2731 2733 2734 2737 2738 2747 2748 2749 2750 2752 2755 2756 2757 2763 2766 2769 2774 2778 2779 2780 2782 2783 2784 2787 2801 2804 2805 2813 2821 2825 2831 2832 2833 2834 2842 2843 2844 2845 2849 2858 2859 2862 2864 2866 2881 2886 2891 2895 2906 2908 2920 2921 2922 2923 2927 2928 2929 2930 2931 2932 2933 2936 2946 2947 2948 2949 2950 2952 2954 2957 2958 2959 2960 2961 2963 2964 2965 2969 2970 2971 2973 2976 2977 2982 2984 2985 2988 2989 2997 2998 2999 3001 3002 3003 3004 3005 3007 3009 3010 3011 3013 3014 3015 3017 3018 3020 3028 3032 3034 3039 3041 3046 3049 3050 3051 3052 3053 3057 3058 3059 3060 3061 3062 3064 3065 3066 3071 3072 3086 3087 3089 3090 3091 3092 3093 3099 3102 3103 3105 3106 3125 3127 3129 3131 3132 3138 3147 3148 3149 3150 3154 3156 3159 3160 3161 3176 3186 3187 3188 3189 3190 3192 3193 3196 3198 3214 3215 3222 3223 3224 3229 3230 3231 3233 3239 3244 3246 3250 3252 3254 3257 3264 3267 3268 3269 3270 3271 ...
# Total words in Word2Vec: 14410
# Words not found in Word2Vec: 4901 (44.47%)

# %% [markdown]
# # Training

# %%
# LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Embedding, Dropout, GlobalAveragePooling1D, Flatten, SpatialDropout1D, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

drop_value = 0.2
# n_dense = 24

# %%
model = Sequential()

model.add(Embedding(
    input_dim=VOCAB_SIZE, 
    output_dim=EMBEDDING_DIM, 
    weights=[embedding_matrix], 
    trainable=True
    ))
# model.add(GlobalAveragePooling1D())
model.add(SpatialDropout1D(drop_value))

model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Dropout(0.3))

model.add(LSTM(32, return_sequences=True))
model.add(Dropout(0.3))

# model.add(GlobalAveragePooling1D())
model.add(Flatten())

# Fully connected layers
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
# model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(1, activation='sigmoid'))

print(model.summary())
# Out:
# I0000 00:00:1746284624.777685      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │       1,102,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout1d (SpatialDropout1D) │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,102,100 (4.20 MB)
#  Trainable params: 1,102,100 (4.20 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# {0: 0.685027541311968, 1: 1.851150202976996}

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5), loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy'])

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))

checkpoint_callback = ModelCheckpoint(filepath='best_model_checkpoint.keras',  
                                      monitor='val_accuracy',
                                      save_best_only=True,
                                      save_weights_only=False,  # Save full model (architecture + weights)
                                      verbose=1)
# early_stop = EarlyStopping(monitor='val_loss', patience=3)

num_epochs = 100
history = model.fit(
    train_texts_padded,
    y_train,
    validation_data=(val_texts_padded,y_val),
    epochs=num_epochs,
    callbacks=[checkpoint_callback],
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# I0000 00:00:1746284708.323112     123 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6591 - loss: 1.3024
# Epoch 1: val_accuracy improved from -inf to 0.73761, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.6595 - loss: 1.3022 - val_accuracy: 0.7376 - val_loss: 1.2484
# Epoch 2/100
# 84/86 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7205 - loss: 1.2222
# Epoch 2: val_accuracy did not improve from 0.73761
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7196 - loss: 1.2220 - val_accuracy: 0.7143 - val_loss: 1.1802
# Epoch 3/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7152 - loss: 1.1626
# Epoch 3: val_accuracy did not improve from 0.73761
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7149 - loss: 1.1624 - val_accuracy: 0.7201 - val_loss: 1.1185
# Epoch 4/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6926 - loss: 1.1181
# Epoch 4: val_accuracy improved from 0.73761 to 0.75510, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6929 - loss: 1.1174 - val_accuracy: 0.7551 - val_loss: 1.0543
# Epoch 5/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7448 - loss: 1.0491
# Epoch 5: val_accuracy improved from 0.75510 to 0.75802, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7447 - loss: 1.0486 - val_accuracy: 0.7580 - val_loss: 0.9853
# Epoch 6/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7601 - loss: 0.9748
# Epoch 6: val_accuracy improved from 0.75802 to 0.78717, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7601 - loss: 0.9742 - val_accuracy: 0.7872 - val_loss: 0.8781
# Epoch 7/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7658 - loss: 0.8687
# Epoch 7: val_accuracy improved from 0.78717 to 0.81924, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7660 - loss: 0.8679 - val_accuracy: 0.8192 - val_loss: 0.7386
# Epoch 8/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8049 - loss: 0.7483
# Epoch 8: val_accuracy improved from 0.81924 to 0.85714, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8051 - loss: 0.7471 - val_accuracy: 0.8571 - val_loss: 0.6121
# Epoch 9/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8638 - loss: 0.5878
# Epoch 9: val_accuracy improved from 0.85714 to 0.89213, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8642 - loss: 0.5869 - val_accuracy: 0.8921 - val_loss: 0.4875
# Epoch 10/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9240 - loss: 0.4470
# Epoch 10: val_accuracy improved from 0.89213 to 0.91837, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9242 - loss: 0.4466 - val_accuracy: 0.9184 - val_loss: 0.4419
# Epoch 11/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9492 - loss: 0.3637
# Epoch 11: val_accuracy improved from 0.91837 to 0.92711, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9492 - loss: 0.3637 - val_accuracy: 0.9271 - val_loss: 0.3961
# Epoch 12/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9623 - loss: 0.3371
# Epoch 12: val_accuracy improved from 0.92711 to 0.93586, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9622 - loss: 0.3369 - val_accuracy: 0.9359 - val_loss: 0.3706
# Epoch 13/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9639 - loss: 0.3156
# Epoch 13: val_accuracy improved from 0.93586 to 0.94461, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9639 - loss: 0.3155 - val_accuracy: 0.9446 - val_loss: 0.3565
# Epoch 14/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9675 - loss: 0.2943
# Epoch 14: val_accuracy did not improve from 0.94461
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9675 - loss: 0.2944 - val_accuracy: 0.9446 - val_loss: 0.3221
# Epoch 15/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9686 - loss: 0.2860
# Epoch 15: val_accuracy improved from 0.94461 to 0.95335, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9686 - loss: 0.2857 - val_accuracy: 0.9534 - val_loss: 0.3195
# Epoch 16/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9768 - loss: 0.2516
# Epoch 16: val_accuracy did not improve from 0.95335
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9768 - loss: 0.2515 - val_accuracy: 0.9534 - val_loss: 0.3121
# Epoch 17/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9784 - loss: 0.2324
# Epoch 17: val_accuracy improved from 0.95335 to 0.95627, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9784 - loss: 0.2323 - val_accuracy: 0.9563 - val_loss: 0.2933
# Epoch 18/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9774 - loss: 0.2383
# Epoch 18: val_accuracy did not improve from 0.95627
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9775 - loss: 0.2381 - val_accuracy: 0.9504 - val_loss: 0.2872
# Epoch 19/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9817 - loss: 0.2057
# Epoch 19: val_accuracy did not improve from 0.95627
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9817 - loss: 0.2058 - val_accuracy: 0.9534 - val_loss: 0.2678
# Epoch 20/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9760 - loss: 0.2016
# Epoch 20: val_accuracy did not improve from 0.95627
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9761 - loss: 0.2015 - val_accuracy: 0.9534 - val_loss: 0.2578
# Epoch 21/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9824 - loss: 0.1788
# Epoch 21: val_accuracy did not improve from 0.95627
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9824 - loss: 0.1789 - val_accuracy: 0.9534 - val_loss: 0.2491
# Epoch 22/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9821 - loss: 0.1890
# Epoch 22: val_accuracy did not improve from 0.95627
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9820 - loss: 0.1889 - val_accuracy: 0.9563 - val_loss: 0.2379
# Epoch 23/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9903 - loss: 0.1581
# Epoch 23: val_accuracy improved from 0.95627 to 0.95918, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9902 - loss: 0.1583 - val_accuracy: 0.9592 - val_loss: 0.2327
# Epoch 24/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9896 - loss: 0.1524
# Epoch 24: val_accuracy did not improve from 0.95918
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9895 - loss: 0.1525 - val_accuracy: 0.9563 - val_loss: 0.2597
# Epoch 25/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9885 - loss: 0.1391
# Epoch 25: val_accuracy did not improve from 0.95918
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9885 - loss: 0.1392 - val_accuracy: 0.9592 - val_loss: 0.2423
# Epoch 26/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9871 - loss: 0.1464
# Epoch 26: val_accuracy did not improve from 0.95918
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9871 - loss: 0.1465 - val_accuracy: 0.9563 - val_loss: 0.2329
# Epoch 27/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9851 - loss: 0.1500
# Epoch 27: val_accuracy did not improve from 0.95918
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9852 - loss: 0.1497 - val_accuracy: 0.9592 - val_loss: 0.2218
# Epoch 28/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9833 - loss: 0.1547
# Epoch 28: val_accuracy did not improve from 0.95918
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9833 - loss: 0.1544 - val_accuracy: 0.9592 - val_loss: 0.2037
# Epoch 29/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9910 - loss: 0.1269
# Epoch 29: val_accuracy improved from 0.95918 to 0.96210, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9910 - loss: 0.1268 - val_accuracy: 0.9621 - val_loss: 0.2008
# Epoch 30/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9882 - loss: 0.1286
# Epoch 30: val_accuracy did not improve from 0.96210
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9882 - loss: 0.1285 - val_accuracy: 0.9621 - val_loss: 0.2021
# Epoch 31/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9889 - loss: 0.1167
# Epoch 31: val_accuracy did not improve from 0.96210
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9889 - loss: 0.1167 - val_accuracy: 0.9621 - val_loss: 0.2048
# Epoch 32/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9883 - loss: 0.1196
# Epoch 32: val_accuracy improved from 0.96210 to 0.96501, saving model to best_model_checkpoint.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9883 - loss: 0.1193 - val_accuracy: 0.9650 - val_loss: 0.1987
# Epoch 33/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9902 - loss: 0.1089
# Epoch 33: val_accuracy did not improve from 0.96501
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9902 - loss: 0.1089 - val_accuracy: 0.9621 - val_loss: 0.1935
# Epoch 34/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9949 - loss: 0.0924
# Epoch 34: val_accuracy did not improve from 0.96501
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.
100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9966 - loss: 0.0112
# Epoch 99: val_accuracy did not improve from 0.97376
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9967 - loss: 0.0111 - val_accuracy: 0.9679 - val_loss: 0.1519
# Epoch 100/100
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9991 - loss: 0.0083
# Epoch 100: val_accuracy did not improve from 0.97376
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9991 - loss: 0.0084 - val_accuracy: 0.9679 - val_loss: 0.1547

# %%
from tensorflow.keras.models import load_model
model = load_model("best_model_checkpoint.keras")

model.save("../Model/LSTM_WORD2VEC_TORCH_EMBEDDING_TRAINABLETRUE.h5")
model.save("../Model/LSTM_WORD2VEC_TORCH_EMBEDDING_TRAINABLETRUE.keras")

# %% [markdown]
# # Eval

# %%
from tensorflow.keras.models import load_model

model = load_model("../Model/LSTM_WORD2VEC_TORCH_EMBEDDING_TRAINABLETRUE.keras")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 16 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
model.evaluate(test_texts_padded, y_test, verbose=0)
# Out:
# [0.17066116631031036, 0.9649122953414917]

# %%
best_epoch = np.argmin(history.history['val_loss']) + 1
best_epoch
# Out:
# 63

# %%
plt.plot(history.history['loss'][:best_epoch], label='loss')
plt.plot(history.history['val_loss'][:best_epoch], label='val_loss')
# plt.ylim([0, 0.2])
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.title("Loss History")
plt.show()

plt.plot(history.history['accuracy'][:best_epoch], label='acc')
plt.plot(history.history['val_accuracy'][:best_epoch], label='val_acc')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.title("Accuracy History")
plt.grid(True)

# %%
from sklearn.metrics import precision_recall_curve, f1_score
from sklearn.metrics import average_precision_score

y_probs = model.predict(test_texts_padded)
y_probs = y_probs.flatten()

precisions, recalls, thresholds = precision_recall_curve(y_test, y_probs)

f1s = 2 * (precisions * recalls) / (precisions + recalls + 1e-8)

best_idx = f1s.argmax()
best_threshold = thresholds[best_idx]

print(f"Best Threshold: {best_threshold:.4f}")
print(f"Best F1-Score: {f1s[best_idx]:.4f}")

ap_score = average_precision_score(y_test, y_probs)
print(f"Average Precision (AP) Score: {ap_score:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# Best Threshold: 0.3280
# Best F1-Score: 0.9462
# Average Precision (AP) Score: 0.9813

# %%
pred = model.predict(test_texts_padded)
y_pred = [0 if pred < best_threshold else 1 for pred in pred]

print(f"Accuracy Score: {accuracy_score(y_pred, y_test)}")
print(f"F1 Score: {f1_score(y_pred, y_test)}")
print(f"Recall Score: {recall_score(y_pred, y_test)}")
print(f"Precision Score: {precision_score(y_pred, y_test)}")
print(f"Classification Report: \n{classification_report(y_test, y_pred, target_names=label_type)}")

display = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred), display_labels = label_type)

fig, ax = plt.subplots(figsize=(6,6))
print(f"Confusion Matrix:\n")
display.plot(ax=ax, xticks_rotation='vertical')
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Accuracy Score: 0.9707602339181286
# F1 Score: 0.9462365591397849
# Recall Score: 0.9361702127659575
# Precision Score: 0.9565217391304348
# Classification Report:
#               precision    recall  f1-score   support
#
# NotPromotion       0.98      0.98      0.98       250
#    Promotion       0.94      0.96      0.95        92
#
#     accuracy                           0.97       342
#    macro avg       0.96      0.97      0.96       342
# weighted avg       0.97      0.97      0.97       342
#
# Confusion Matrix:

# %%
for idx,i in enumerate(y_pred):
    if i != y_test[idx]:
        print(idx+1,")❌pred:", i, "| label:", y_test[idx], texts_test[idx])
        continue
    print(idx+1,") pred:", i, "| label:", y_test[idx], texts_test[idx])
# Out:
# 1 ) pred: 1 | label: 1 INFO CINA777APK CINA777RTP CINA777Logo24/11/2024 ( Min ) 14.56 ( GMT+07 ) Versi MobileVersi WAP ( NEX4D ) Nama PenggunaKata SandiLupa Kata Sandi ? DaftarHomeTogelHot GamesSlotsLive CasinoOlahragaCrash GameArcadePokerE-SportsSabung AyamPromosiWelcome to situs resmi CINA777 | Kami membayar berapapun kemenangan player.HasilPasaranBuku MimpiHasil TerakhirStatistik MarketGame PopulerMahjong Wins 3 – Black ScatterMAINMahjong Wins 3 – Black ScatterMahjong WaysMAINMahjong WaysMighty HerculesMAINMighty HerculesSlot88 BonanzaMAINSlot88 BonanzaLe PharaohMAINLe PharaohPirate Quest 1000MAINPirate Quest 1000SixSixSixMAINSixSixSixWay of NinjaMAINWay of Ninja888 GoldMAIN888 GoldMahjong Ways 2MAINMahjong Ways 2Gates of Olympus 1000™MAINGates of Olympus 1000™Wild Bounty ShowdownMAINWild Bounty ShowdownLucky Twins NexusMAINLucky Twins NexusNexus Koi GateMAINNexus Koi GateThe CryptMAINThe CryptLucky Twins Power ClustersMAINLucky Twins Power ClustersMentalMAINMentalFortune Gems 2MAINFortune Gems 2Hot Hot NexusMAINHot Hot NexusFortune GemsMAINFortune GemsMetode PembayaranBersertifikasi DariTanggung Jawab BermainGambling SupportGambling Support18 Plus18 PlusBrowser Yang DidukungChromeChromeEdgeEdgeFirefoxFirefoxSukses Profit Bermain Game Online Situs Terbaik CINA777Hi pencari cuan permainan spin game online indonesia , website CINA777 menyediakan provider provider terlengkap pastinya menambah peluang kemenangan terbesar bermain . Tentunya memberikan bonus member baru lama hari senilai 100.000 ribu rupiah dimainkan seluruh permainan withdraw kapan . Ayo segera coba daftar akun cina777 sekarang rasakan perbedaan putaran jackpot betah bermain hari meraih pundi pundi mencari ani ani daerah.SALAM CUAN DAN PROFIT BERSAMA BO CINA777Logo©2024 CINA777 . Hak cipta dilindungi | 18+
# 2 ) pred: 0 | label: 0 sayang ga download
# 3 ) pred: 1 | label: 1 situs resmi slot online uang asli joker whatsapp 0852-1599-2699
# 4 ) pred: 0 | label: 0 maaf : grinning_squinting_face :
# 5 ) pred: 0 | label: 0 Paket komplit tim nya full drak sistem😂😂
# 6 ) pred: 0 | label: 0 kok tiba tiba selesai sii bang streaming nyaaa
# 7 ) pred: 0 | label: 0 berasa tempat hhhhh
# 8 ) pred: 0 | label: 0 WKWKW KESAL MAKSIMAL SII
# 9 ) pred: 0 | label: 0 0:14 Bang jo , emblem buildnya apa aja ? Kasi tau dong : )
# 10 ) pred: 1 | label: 1 MANUT88 emang terkenal gampang pecaah coy
# 11 ) pred: 0 | label: 0 Ninja cok
# 12 ) pred: 0 | label: 0 EMPACTION WOYYYYYYY
# 13 ) pred: 1 | label: 1 Wow ! JP sangat fantastis D3WADOR4 , memecahkan rekor ! 😵 😵‍💫
# 14 ) pred: 0 | label: 0 cerahkan hariharimu
# 15 ) pred: 0 | label: 0 SKEMM
# 16 ) pred: 0 | label: 0 jelas lebih enak
# 17 ) pred: 1 | label: 1 DEWA-D0RAtuh stus tau banget apa gua butuhin ! 😱 😳
# 18 ) pred: 0 | label: 0 gelooo ngakak kaliii wwkkwkw
# 19 ) pred: 1 | label: 1 pulau777 bikin untung tiap hari , WD jalan terus !
# 20 ) pred: 0 | label: 0 Strimer bohong
# 21 ) pred: 0 | label: 0 semuanya aja diledakin
# 22 ) pred: 0 | label: 0 nah baru the real what a game , gilak ga sia-sia nonton 3 jam lebih sebagus seseru , doey sedih bgt , he do n't deserved that , gbsa hidup lg kek kissy trnyata msh hidup😢
# 23 ) pred: 0 | label: 0 adzan boss adzan
# 24 ) pred: 0 | label: 0 bang telat ga😔
# 25 ) pred: 0 | label: 0 Game musibah simulator
# 26 ) pred: 0 | label: 0 wkwkwk saking panik nya sampe end stream😭
# 27 ) pred: 0 | label: 0 pertama
# 28 ) pred: 0 | label: 0 Ahhhhh
# 29 ) pred: 1 | label: 1 Main DEWADORАbikin hariku lebih menyenangkan , terima kasih !
# 30 ) pred: 0 | label: 0 ubur ubur ikan lele main Popy playtime chapter 4 le😾😾
# 31 ) pred: 0 | label: 0 rorrr
# 32 ) pred: 1 | label: 1 Mencari kegiatan baru ? AERO88 menawarkan pengalaman menarik .
# 33 ) pred: 1 | label: 1 A E R O 8 8 emang top notch , highly recommended buat semua kalangan !
# 34 ) pred: 0 | label: 0 Hari kamis bang buka hari selasa , sampe panik ku lihat kalender😭
# 35 ) pred: 0 | label: 0 makanya jadi anak jangan sombong jangan suka takabur bang
# 36 ) pred: 1 | label: 1 Hari indah penuh kebahagiaan bersama DEWADORA , rezeki datang menghampiri diduga !
# 37 ) pred: 0 | label: 0 Kocak lu bang 🗿
# 38 ) pred: 0 | label: 0 Bang coba cari misteri FUSION KRAKEN bang☠️😶‍🌫️
# 39 ) pred: 0 | label: 0 haloo bangg windahh
# 40 )❌pred: 1 | label: 0 lengkap gak ribet paket hebat hemat banget rp ribuan
# 41 ) pred: 0 | label: 0 Jogja ku Istimewa ...
# 42 ) pred: 0 | label: 0 14:41
# 43 ) pred: 0 | label: 0 Ollie perwujudan bocil lag manipulatif kimak
# 44 ) pred: 0 | label: 0 gendong ? lo early gendong junggler late menggila
# 45 ) pred: 1 | label: 1 Auto sultan bareng PULAU777 , cuaan mulu !
# 46 ) pred: 0 | label: 0 maaf nama Aisyah humaira.maaf kalo gj tadi : smiling_face_with_tear : :pensive_face :
# 47 ) pred: 0 | label: 0 mana horornyaaaa
# 48 ) pred: 0 | label: 0 penuhi nutrisimu ollate susu buah sehat asal korea
# 49 ) pred: 0 | label: 0 HUGGY WUGGY MASIH HIDUP KARENA DIA CUMAN TERJATUH PADA AWAL CHAPTER 1 , DAN IA DI CHAPTER 4 INGIN MEMBUNUH KARAKTER UTAMA KARENA MEMILIKI DENDAM , KISSY MISSY JUGA BELUM TENTU BENAR BENAR MATI TANGAN IA PUTUS SAAT INGIN MENYELAMATKAN KARAKTER UTAMA SETELAH ITU IA BERSEMBUNYI UNTUK MENGHINDAR DARI PROTOTYPE
# 50 ) pred: 0 | label: 0 Waw game misterius
# 51 ) pred: 1 | label: 1 Anda luar biasa , Pulau777 !
# 52 ) pred: 0 | label: 0 Yoi ! ! ! ! ! Popoy . Playtime udah rilis awal banget 🎉🎉🎉🎉🎉 bravoo ! ! ! ! 💯💯💯🎉🎉🎉🔥🔥🔥🔥🔥
# 53 ) pred: 0 | label: 0 Prapatan jetis tulung drone sisan min : grinning_face_with_sweat :
# 54 ) pred: 0 | label: 0 nice try bang ! ! ! kali jangan emot bang ?
# 55 ) pred: 0 | label: 0 1:22:10 apa sih bng hhh
# 56 ) pred: 1 | label: 1 & quot ; Waduh , savage-nya epic , kok kalah ? Yuk buktikan skill-mu 168wbtoto , tempat gamers sejati berkumpul ! & quot ;
# 57 ) pred: 1 | label: 1 & quot ; Kalah savage tuh sakit sih , cuan 168wbtoto ! & quot ;
# 58 ) pred: 1 | label: 1 WebsiteLogo Masuk Daftar sportsbook slot casino lottery arcade livegames Live Game BIOSKOP777 SITUS WEBSITE TERBAIK MENYALA ABANGKUH merupakan nomor satu banyak pilihan permainan terlengkap masa kini , keamanan gampang akses penting abangku . Beranda APK Chat Promosi
# 59 ) pred: 0 | label: 0 DAN YAP END 😭
# 60 ) pred: 0 | label: 0 Bg hape ku rusak gak nonton sekarang pake hape mamah
# 61 ) pred: 0 | label: 0 Bang jangan tunda waktu live gw laper klo lu gak livestream
# 62 ) pred: 0 | label: 0 Malah diketawain sama tim
# 63 ) pred: 0 | label: 0 Bang main fisch soal nya udh update atlantis semoga baca❤
# 64 ) pred: 0 | label: 0 * _JEMBER HADIR_ *
# 65 ) pred: 0 | label: 0 keren kak butakkk😂
# 66 ) pred: 0 | label: 0 😂kalah mulu ketuaa
# 67 ) pred: 0 | label: 0 Kok histori nya banyak kalah bang , gua winstreak berarti udh masum rrq la
# 68 ) pred: 0 | label: 0 gak live chatnya 😢
# 69 ) pred: 1 | label: 1 Detak jantung berpacu kencang menunggu JP DEWADORA , akhirnya pecah jackpotnya !
# 70 ) pred: 0 | label: 0 hari mood akuuu jelekk pms day 1 ehhh bang windahh live maenn pvz autooo senengggg , makasihhh yaaa bangg jaga kesehatannyaa yaaaa🫶🏻🫶🏻🫶🏻
# 71 ) pred: 0 | label: 0 menit awal 39:38 game anak tk menit akhir jadi eL Blunder
# 72 ) pred: 0 | label: 0 stop sombong ninja ! ! ! 😭😭
# 73 ) pred: 0 | label: 0 Enak bgt lo ngatain anak2 bodoh ! ! mentalnya sama kaya guru nanya anak murid ga tau jawabannya terus dikatain bodoh ! Ga dibiarin kebiasaan kaya gini dasar orang tua bodoh beradab ! !
# 74 ) pred: 0 | label: 0 6:27 baru 6 menit udh gakuat gua nontonnya
# 75 ) pred: 0 | label: 0 atasi sakit kepala cepat
# 76 ) pred: 0 | label: 0 Hadirr bang
# 77 ) pred: 0 | label: 0 pertama bg
# 78 ) pred: 0 | label: 0 selamat Sukses , 268 tahun kota Jogja tercinta : red_heart :
# 79 ) pred: 0 | label: 0 Langsung Saja
# 80 ) pred: 0 | label: 0 Semoga Trending😂😂😂
# 81 ) pred: 0 | label: 0 baru masuk udahan
# 82 ) pred: 0 | label: 0 nyaman langkah
# 83 ) pred: 0 | label: 0 EL PINGSAN
# 84 ) pred: 0 | label: 0 Burger elemen api , air , angin , tanah lalu endstream
# 85 ) pred: 0 | label: 0 Game bintang 1 sejarah game aseli
# 86 ) pred: 0 | label: 0 NINJAAAA
# 87 ) pred: 0 | label: 0 bang lucu banget hhhhh🤣🤣🤣🤣🤣
# 88 ) pred: 0 | label: 0 bang cobain pvz hybrid pgn tau
# 89 ) pred: 0 | label: 0 kok gbsa download bang
# 90 ) pred: 1 | label: 1 Bahagia banget rezeki berkah D3WADOR4 ! 😗 😘
# 91 ) pred: 0 | label: 0 rambut indah percaya diri maksimal
# 92 ) pred: 0 | label: 0 Hahaa biasanya ninja wkwkw
# 93 ) pred: 0 | label: 0 9:46 gimana gak suren , sadar beliau menantang turet 😂
# 94 ) pred: 0 | label: 0 KANGEN UWU GIRL SAMA LAUNDRY SIMULATOR BANGGGGGGGGGGGG
# 95 ) pred: 0 | label: 0 1:22:19 penyebab kalah
# 96 ) pred: 1 | label: 1 Wih , JP diAERO88 , rezeki emang berpihak !
# 97 ) pred: 0 | label: 0 0.49 Ama Hero Hero nya pula tukar muka nya wkwkw
# 98 ) pred: 1 | label: 1 DEW4DOR4 menawarkan pendekatan berbeda interaksi daring . 🥰 😍
# 99 ) pred: 0 | label: 0 cantikkk sekalii
# 100 ) pred: 0 | label: 0 Kocak el kungfu
# 101 ) pred: 1 | label: 1 Hal pertama pikirkan mendengar nama Pulau777 kepercayaan .
# 102 ) pred: 0 | label: 0 kok end bang
# 103 ) pred: 0 | label: 0 3:10:25 Uchiha Doey : ' ( kasihan banget
# 104 ) pred: 0 | label: 0 mek dut cos
# 105 ) pred: 0 | label: 0 Ubur-ubur ikan lelee panik dikit end leee
# 106 ) pred: 1 | label: 1 Merasa sangat senang mendapatkan rezeki berkah AERО88 !
# 107 ) pred: 0 | label: 0 EMPACTIONN WOYY
# 108 )❌pred: 0 | label: 1 𝗱𝟯𝗣𝟬 𝟭𝟬𝟬 j𝗱 𝟮𝗷𝘁 buruan gas 𝗚𝗔𝗥𝗔𝗡𝗦𝗜 𝟭𝟬𝟬 % : fire : 𝗠𝗘𝗧𝗘𝗢𝗥𝗪𝗜𝗡 : fire :
# 109 ) pred: 1 | label: 1 bonus sambar petir gate of olympus hingga idr 488.000 slot
# 110 ) pred: 0 | label: 0 hari hari ninja
# 111 ) pred: 0 | label: 0 end jir
# 112 ) pred: 0 | label: 0 kasian bang . Banyak musuh , lu jadinya kalah wkwk 1:24:33
# 113 ) pred: 0 | label: 0 Col😂
# 114 ) pred: 0 | label: 0 Y
# 115 ) pred: 0 | label: 0 bg kapan main fc mobile ? 😌😞😅
# 116 ) pred: 0 | label: 0 Bang main gta6
# 117 ) pred: 0 | label: 0 bang aktifin donlotnya gada kuota
# 118 ) pred: 1 | label: 1 Gak pernah bosan main .AERO88. , selalu baru !
# 119 )❌pred: 0 | label: 1 free spin & buy spin batal
# 120 ) pred: 0 | label: 0 Gg bang 3 jam baru kelar gameny wkwkwk😂😂
# 121 ) pred: 0 | label: 0 Bakso krispy 😂😂😂😂
# 122 ) pred: 0 | label: 0 kebanyakan gaya jadi kalah kan wkwkwkwk
# 123 ) pred: 1 | label: 1 Main AEЯO88-bikin hati bahagia banget , hasilnya gacir terus !
# 124 ) pred: 0 | label: 0 Kapan Menangnya bang col , masa kalah mulu😅
# 125 ) pred: 0 | label: 0 1:24:24 ditakdirkan menang🗿🗿
# 126 ) pred: 0 | label: 0 Napa tiba '' selesai bg
# 127 ) pred: 0 | label: 0 Kocak wkwkwkwkwkwkwk🤣🤣🤣🤣
# 128 )❌pred: 0 | label: 1 Join membership : https : //www.youtube.com/channel/UCmtAg_U0wvmWdxTlceISdEw/join Top up diamond sekali kedip : https : //empe.shop/
# 129 ) pred: 1 | label: 1 Main AERO88 auto good vibes , rezeki emang udah ngatur !
# 130 ) pred: 0 | label: 0 baru masuk udh end🥰
# 131 ) pred: 1 | label: 1 DEWADOЯA main bentar aja , saldo langsung naik
# 132 ) pred: 1 | label: 1 P U L A U 7 7 7 benar-benar memberi pengalaman luar biasa !
# 133 )❌pred: 1 | label: 0 Salam Malaysia bang ❤
# 134 ) pred: 0 | label: 0 1:11:47 tangan kanan kiri sekarang berulah
# 135 ) pred: 1 | label: 1 Gua selalu pilih DEWA-D0RAbuat maen , soalnya ga pernah ngecewain ! 🤯 😳
# 136 ) pred: 1 | label: 1 Savage game , kalah ? Gak apa-apa , coba Asiktoto buktikan ! 🎰🔥
# 137 ) pred: 0 | label: 0 gg windah beladirinya bang
# 138 ) pred: 0 | label: 0 Hahahahahahaha😂😂😂😂
# 139 ) pred: 0 | label: 0 gaya nyaman
# 140 ) pred: 1 | label: 1 Tidak mengecewakan pulau777 , semuanya sesuai harapan .
# 141 ) pred: 1 | label: 1 Saya selalu merekomendasikan Pulau777 teman-teman .
# 142 ) pred: 1 | label: 1 Seru banget main DORA77 , hasilnya bikin hati senang terus ! 😫 😤
# 143 ) pred: 0 | label: 0 yaahh end donk 😂
# 144 ) pred: 0 | label: 0 Bang live
# 145 ) pred: 0 | label: 0 pertama bang
# 146 ) pred: 1 | label: 1 Mantap jiwa main D3WADOR4 , rezeki nomplok tiap hari ! 😪 😴
# 147 ) pred: 0 | label: 0 ubur ubur ikan lele , udah seneng malah kalah leee🤭🤭🤭
# 148 ) pred: 1 | label: 1 Masuk Daftar |TOGEL|SLOT|LIVE CASINO|SPORT|ARCADE|SABUNG|INTERACTIVE| PROMOSI Informasi terbaru : Minimal Spin turun menjadi Rp 400 . | Ingat LINK LOGIN : vpnpenta.cc - loginpenta.ccTransaksi Kami Menerima Pembayaran Dibawah Ini Bank Lokal BCA Mandiri BNI BRI CIMB Danamon Permata PANIN OCBC DKI SUMUT BSI JAGO E Money & Pulsa Jenius DANA OVO GOPAY LinkAja Lain-lain Kontak Kami WHATSAPP +62 822-9567-3439 t.me/pentaslotvip • TENTANG KAMI | • BANTUAN | • PERATURAN | • INFORMASI BANK | • HUBUNGI KAMI | • KEBIJAKAN PRIVASI | • PERSETUJUAN COOKIES PentaSlot Link Alternatif Situs Game Online Gacor PAY4D Selamat bergabung situs pentaslot server permainan game online paling gacor Pay4d nomor satu indonesia . Game rtp kemenangan persentase paling besar permainan . Selalu memberikan banyak bonus seluruh member hari bermain website game online terpopuler pencarian pentaslot4d pilihan game pay4d produk tebak 4 angka terbaik . PENTASLOT . All Rights Reserved . MOBILE WAP LAPOR PUSAT MEMBER SERVICE+62 822-9567-3439 t.me/pentaslotvip Kami menggunakan cookies mengoptimalkan navigasi , fitur konten lebih Relevan . Untuk informasi lengkap cookies silahkan lihat Persetujuan Cookies . Dengan menggunakan situs , Anda menyetujui penggunaan cookies data pribadi sesuai Kebijakan Privasi .
# 149 ) pred: 0 | label: 0 Cess😂
# 150 ) pred: 0 | label: 0 Burger butuh defense kuat
# 151 ) pred: 0 | label: 0 3:18:16 HEEESSSS ' BACCCKKK🔥🔥🔥
# 152 ) pred: 0 | label: 0 Ternyata wujud asli fir'aun korupsi terus udah bayar tpi ga diajak mabar 😡
# 153 ) pred: 0 | label: 0 strimer ninja
# 154 ) pred: 0 | label: 0 windah batubara : sombong kalah kemudian
# 155 ) pred: 1 | label: 1 judi slot online big bonus slot daftar sekarang
# 156 ) pred: 0 | label: 0 Akhir nya upload keratua juga😂
# 157 ) pred: 0 | label: 0 AVATAR MOMENT
# 158 ) pred: 0 | label: 0 sribit jogja hadir
# 159 ) pred: 0 | label: 0 telat 😔 baru joinn
# 160 ) pred: 1 | label: 1 Bermain bersama teman-teman diAERO88 semakin seru asyik , semakin banyak pula rezekinya !
# 161 ) pred: 0 | label: 0 What a game 🤚😐🤚
# 162 ) pred: 0 | label: 0 malu berat😹
# 163 ) pred: 0 | label: 0 Bg borong mistery shop ff banyak ubdate baru
# 164 ) pred: 0 | label: 0 kalah lsung end bangg😭
# 165 ) pred: 1 | label: 1 Gercep banget jp nyaGaruda-hoki😱
# 166 ) pred: 0 | label: 0 Pertama apa nih Edit : GG banget bang windah pas lawan The doctor behh gercep bet GG banget bang
# 167 ) pred: 1 | label: 1 Main bareng teman AERO88 makin seru , makin banyak cuan !
# 168 ) pred: 1 | label: 1 Saya penggemar berat Pulαυ777 !
# 169 ) pred: 1 | label: 1 Teman-teman merekomendasikan pulau777 , ternyata memang bagus .
# 170 ) pred: 1 | label: 1 Selalu keseruan baru PULAU777 .
# 171 ) pred: 1 | label: 1 Main AERO88 bikin nagih ! Pengen main terus !
# 172 ) pred: 0 | label: 0 End
# 173 ) pred: 0 | label: 0 PERTAMAA BANG
# 174 ) pred: 0 | label: 0 MK : lu terlalu overthinking
# 175 ) pred: 0 | label: 0 Mantap
# 176 ) pred: 0 | label: 0 Makanya bang jadi anak jangan sombong . Ingat hidup kadang atas kadang bawah . Kadang menang kadang kalah . Kadang datang , kadang mengilang , kayak ninja
# 187 ) pred: 0 | label: 0 Ini live kapan bang cari yt ko ga
# 188 ) pred: 0 | label: 0 Bng besok cobain mode hero bg tanamannya dikontrol pake wasd
# 189 ) pred: 0 | label: 0 adu domba sama ollie biar doey mati bang
# 190 ) pred: 0 | label: 0 menyala kemantren Gedongtengen
# 191 ) pred: 0 | label: 0 bang lu sadar ga sih kerucut lalu lintas , tanda panah biru , sama kotak putih tanda
# 192 ) pred: 0 | label: 0 Makanya jangan sombong
# 193 ) pred: 0 | label: 0 1:23:00 Ibnu jangan emot dulu Ibnu😹🙏
# 194 ) pred: 1 | label: 1 Jakpot langsung mengalir , buruan coba DEWAD0RA ! Kamu dapet ! 😫 😤
# 195 ) pred: 1 | label: 1 Alhamdulillah , rezeki lancar hari berkat AERO88 !
# 196 ) pred: 1 | label: 1 DEWADOЯA gua baru coba , ternyata gampang banget menangnya
# 197 ) pred: 1 | label: 1 JP beruntun DEWADORA , hoki banget nih !
# 198 ) pred: 0 | label: 0 WKWKWKKKKKK KETAWAAAAA
# 199 ) pred: 0 | label: 0 Live full ngeyapping
# 200 ) pred: 1 | label: 1 -Ga Ruda-Ho ki-gokil banget pecah terus ga sia sia anjaay🔥
# 201 ) pred: 0 | label: 0 cantik alami mustika ratu pilihannya
# 202 ) pred: 0 | label: 0 Bang main ff
# 203 ) pred: 0 | label: 0 el stresssss 1:22:32
# 204 ) pred: 0 | label: 0 AKU NONTON 3 JAM TAPI GA DI NOTICE
# 205 ) pred: 0 | label: 0 Tukang ninjaaaaaa
# 206 ) pred: 1 | label: 1 Tak disangka sebanyak DEWADOЯA , auto berbagi rezeki !
# 207 ) pred: 0 | label: 0 ahai
# 208 ) pred: 1 | label: 1 Nggak nyesel coba main DEWАDORA , hasilnya gacir banget !
# 209 ) pred: 1 | label: 1 Modal receh main .AERO88. , untungnya berlipat ganda !
# 210 ) pred: 1 | label: 1 Terima kasih tim Pulαu777 sangat membantu !
# 211 ) pred: 0 | label: 0 B
# 212 ) pred: 0 | label: 0 Baru datang langsung end
# 213 ) pred: 0 | label: 0 bang mukamu burem bang
# 214 ) pred: 0 | label: 0 Always ngakak pas ketiban tiang
# 215 ) pred: 1 | label: 1 Sukses selalu PULAU777 !
# 216 ) pred: 0 | label: 0 cowo kan
# 217 ) pred: 0 | label: 0 Kebanyakan gaya , awokwok malu😂😂😂
# 218 ) pred: 0 | label: 0 Wkwkwkwkkw
# 219 ) pred: 0 | label: 0 Game cocok orang kesabarannya setipis tisu wkwkwkwk
# 220 ) pred: 1 | label: 1 Awalnya iseng doang main AERO88 , eh malah ketagihan ! Cuan terus nih !
# 221 ) pred: 0 | label: 0 Perkatanan bang windah generator sangat sus/mencurigakan kemungkinan besar poopy menjebak doey aksi lancar aksiitu selesai doey generator perbaiki generator Poppy menyuruh bom bawah tanah , pengen tau tau siapa balik prototype SEKIAN DARI TANGGAPAN SAYA MAAF KALO AGA ANEH❤
# 222 ) pred: 1 | label: 1 Coba-coba main D3WADOR4 , eh malah jadi pro , cuan terus nih ! 😝 🤑
# 298 ) pred: 0 | label: 0 Seruu ni game😆
# 299 ) pred: 0 | label: 0 100 % Run In Game : 58:42 Fluke from bagasi pipa Gege banget lo
# 300 ) pred: 1 | label: 1 Gokil ! JP gede banget nih DEWADORA , rekor baru !
# 301 ) pred: 0 | label: 0 32:38 `` Safe & Sound '' Malah diputerin tuh lagu🤣
# 302 ) pred: 0 | label: 0 What a game bro
# 303 ) pred: 1 | label: 1 Saya menikmati pengalaman Pulau777 .
# 304 ) pred: 0 | label: 0 EL SOMBONG
# 305 ) pred: 1 | label: 1 Tidak tempat Pulau777 bermain online .
# 306 ) pred: 0 | label: 0 hallo bangg
# 307 ) pred: 1 | label: 1 Penasaran DEW4DOR4 ? Layak dieksplorasi . 🤔 🤭
# 308 ) pred: 0 | label: 0 gk sabar poppy playtime chapter 4 nya🙄
# 309 ) pred: 1 | label: 1 Tetaplah hebat , Pulau777 !
# 310 ) pred: 0 | label: 0 Ketiduran bjir nonton 😂 pas bangun tiba2 udah teleport aja. , yaudah langsung off in paket + matikan hp otw lanjut tidurv🗿
# 311 ) pred: 1 | label: 1 DEWADОRA cba bentar , eh lngsg WEDEY gede
# 312 ) pred: 0 | label: 0 JAM 4 TAPI PEMBUKAAN
# 313 ) pred: 0 | label: 0 salah siapa malah santai
# 314 ) pred: 0 | label: 0 Bang main game pvz Hybrid Atau gak Game ONE PIECE FIGHTING PATH
# 315 ) pred: 1 | label: 1 Teman-teman menang , ikutan coba , akhirnya dapet jakpot DEWAD0RA ! 😵 😵‍💫
# 316 ) pred: 0 | label: 0 Next episode dapetin anime baru bang
# 317 ) pred: 0 | label: 0 hari hari kamis bang
# 318 ) pred: 0 | label: 0 `` hati2 dijalan '' '' kabari kalau udah sampe rumah '' game mengajarkan pentingnya mengatakan kpd org tersayang sedang dijalan
# 319 ) pred: 0 | label: 0 mantab ketua
# 320 ) pred: 0 | label: 0 Bang main cisini stories
# 321 ) pred: 0 | label: 0 gem bikin tras issu
# 322 ) pred: 0 | label: 0 Bang mainin game fresh kayak gini dong , lucu banget wkwjakwk
# 323 ) pred: 0 | label: 0 bang takut bang minta peyuk soalnya prototype mengerikan sekali
# 324 ) pred: 0 | label: 0 Bg plis main castle crush selalu komen GK pernah mainin😢😢😢
# 325 ) pred: 1 | label: 1 Main A-ERO88 auto happy , rezeki emang diatur !
# 326 ) pred: 0 | label: 0 sok pentantang petenteng
# 327 )❌pred: 1 | label: 0 Mekari Jurnal Fitur Solusi Resources Harga ID Sign In Hubungi Sales Coba Gratis Management Accounting 8 min read 14 Aplikasi Dompet Digital / E-Wallet Terbaik Indonesia Vely Sia Tayang 23 Mar 2023 Diperbarui 18 Jan 2024 Bagikan artikel TwitterTwitter WhatsappWhatsapp LinkedinLinkedin FacebookFacebook Cari sini Daftar Isi Rekomendasi Untuk iOS Android Tips Memilih Tepat e wallet Temukan beberapa ( e-wallet ) lengkap kelebihan dimiliki kemudahan transaksi keuangan Anda ! Kebutuhan masyarakat alat pembayaran praktis mendorong munculnya banyak menaw
# 342 ) pred: 0 | label: 0 Sakit hati team Mabar idiot sakit hati penonton gak ad otak ... 🤣🤣🤣

# %%
from sklearn.metrics import precision_recall_curve, auc

# Compute precision-recall values for class 1 (positive class)
precision_1, recall_1, _ = precision_recall_curve(y_test, y_pred)

# Compute precision-recall values for class 0 (negative class)
y_scores_neg = 1 - np.array(y_pred)  # Since model predicts class 1 probabilities, class 0 is (1 - probability)
precision_0, recall_0, _ = precision_recall_curve(1 - y_test, y_scores_neg)

# Plot Precision-Recall curves for both classes
plt.figure(figsize=(6, 5))
plt.plot(recall_1, precision_1, marker='.', label=f'Class Promotion (1)', color='blue')
plt.plot(recall_0, precision_0, marker='.', label=f'Class Non Promotion (0)', color='red')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves for Both Labels')
plt.legend()
plt.grid()
plt.show()

# %%
def predict_sentiment(text):
    use_text,_ = preprocess_text(text)
    # inputs = tokenizer(use_text, padding=True, truncation=True, return_tensors='tf', max_length=512)
    use_text = tokenizer.texts_to_sequences(use_text)
    use_text = pad_sequences(use_text, maxlen=MAX_LEN, padding='post', truncating='post')

    pred = model.predict(use_text)
    # pred_labels = tf.argmax(pred, axis=1)
    pred_labels = [0 if pred < best_threshold else 1 for pred in pred]
    # print(pred)
 
    pred_labels = [label_type[label] for label in pred_labels]
    for index, preds in enumerate(pred_labels):
        print(f"{text[index]}: {preds}")
text = [
    "Aku adalah seorang mahasiswa",
    "Judi Online Disebut Masuk Tahap Sosial, Cak Imin: 8,8 Juta Pasien Minta Direhabilitasi Jumat, 15 Nov",
    "Gacor xxtoto menang pasti dibayar",
    "dp jd jt buruan gas garansi meteorwin",
    "gacor pasti menang di xxtoto",
    "top up di kantorbola pasti gampang menangnya",
    "gratis koin buruan topup di agencasinoindonesia",
    "gratis koin buruan topup di fairbet88.com, segera daftarkan akun anda",
    "DEWA-DORA tuh situs yang paling enak withdraw tiap hari! 😖 😣",
    "DEWA-DORA tuh situs    yang paling gampang narik tiap hari! 😖 😣",
    "Gua setia maen di DEWADORA, tempat terbaik!",
    "kantorbola99.club - Mau Jackpot x50 x100 x500 x1000 pasti dibayar ? gabung dan Menang berapapun dibayar.",
    "dapatkan banyak rejekii di DEWADORА!"
]
predict_sentiment(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Aku seorang mahasiswa: NotPromotion
# Judi Online Disebut Masuk Tahap Sosial , Cak Imin : 8,8 Juta Pasien Minta Direhabilitasi Jumat , 15 Nov: NotPromotion
# Gacor xxtoto menang pasti dibayar: Promotion
# dp jd jt buruan gas garansi meteorwin: NotPromotion
# gacor pasti menang xxtoto: Promotion
# top up kantorbola pasti gampang menangnya: NotPromotion
# gratis koin buruan topup agencasinoindonesia: NotPromotion
# gratis koin buruan topup fairbet88.com , segera daftarkan akun: NotPromotion
# DEWA-DORA tuh situs paling enak withdraw tiap hari ! 😖 😣: Promotion
# DEWA-DORA tuh situs paling gampang narik tiap hari ! 😖 😣: Promotion
# Gua setia maen DEWADORA , tempat terbaik !: Promotion
# kantorbola99.club - Mau Jackpot x50 x100 x500 x1000 pasti dibayar ? gabung Menang berapapun dibayar .: Promotion
# dapatkan banyak rejekii DEWADORА !: NotPromotion
