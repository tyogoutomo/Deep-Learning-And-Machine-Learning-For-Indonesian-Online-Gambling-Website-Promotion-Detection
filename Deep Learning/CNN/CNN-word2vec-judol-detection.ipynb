# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix,recall_score,precision_score,f1_score,fbeta_score
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
import numpy as np
import matplotlib.pyplot as plt
import pickle

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout,BatchNormalization,Flatten,Conv1D, Embedding,GlobalMaxPooling1D,Input
from tensorflow.keras.models import Sequential

#%pip install Sastrawi
#!unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

from transformers import BertTokenizer
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#!pip install gensim
from gensim.models import Word2Vec
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
combined_data = pd.read_csv('/kaggle/input/dataset-scraping-sendiri/dataset_combined_new - dataset_combined_new.csv', encoding='utf-8', index_col=False)
train_data=pd.read_csv('/kaggle/input/dataset-scraping-sendiri/train.csv')
val_data=pd.read_csv('/kaggle/input/dataset-scraping-sendiri/val.csv')
test_data=pd.read_csv('/kaggle/input/dataset-scraping-sendiri/test.csv')

# %%
combined_data.shape
# Out:
# (3895, 2)

# %%
#check text datatypes
combined_data.dtypes
# Out:
# text     object
# label     int64
# dtype: object

# %%
#Ensure string datatypes
combined_data['text']=combined_data['text'].astype(str)
train_data['text']=train_data['text'].astype(str)
val_data['text']=val_data['text'].astype(str)
test_data['text']=test_data['text'].astype(str)

# %%
stop_factory = StopWordRemoverFactory()
stopwords = stop_factory.get_stop_words()
custom_stopwords = ['aku', 'yg', 'kamu','gw','lu','lo','gua']
stopwords += custom_stopwords

pattern = r"[^A-Za-z ]"
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = re.sub(r"[^A-Za-z ]", "", text.lower())  # Remove non-alphabet characters
    word_list = word_tokenize(text)
    word_list = [word for word in word_list if word not in stopwords]
    return " ".join(word_list)

# %%
combined_data['text'] = combined_data['text'].apply(preprocess_text)
train_data['text']=train_data['text'].apply(preprocess_text)
val_data['text']=val_data['text'].apply(preprocess_text)
test_data['text']=test_data['text'].apply(preprocess_text)

# %%
texts = combined_data['text'].values
labels = combined_data['label'].values

train_texts = train_data['text'].values
train_labels = train_data['label'].values

val_texts = val_data['text'].values
val_labels = val_data['label'].values

test_texts = test_data['text'].values
test_labels = test_data['label'].values

# %%
texts
# Out:
# array(['game slot online terpercaya winning sering kasih bonus',
#        'raffi situs resmi slot gacor anti rungkad terbaik bandar togel terpercaya indonesia',
#        'sendok bonus deposit redeposit', ..., 'kocaaakkkkk', 'panikk',
#        'malah end'], dtype=object)

# %%
combined_data['label'].value_counts()
# Out:
# label
# 0    2661
# 1    1234
# Name: count, dtype: int64

# %%
label_counts = combined_data['label'].value_counts()
plt.figure(figsize=(8, 6))
label_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Customize the plot
plt.title('Distribution of Labels', fontsize=14)
plt.xlabel('Labels', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Separate the texts by class
promotion_texts = texts[labels == 1]
non_promotion_texts = texts[labels == 0]

# Generate wordcloud for each class
promotion_wordcloud = WordCloud(width=800, height=400, background_color='black').generate(' '.join(promotion_texts))
non_promotion_wordcloud = WordCloud(width=800, height=400, background_color='black').generate(' '.join(non_promotion_texts))

# Plot the wordclouds
fig, axes = plt.subplots(1, 2, figsize=(14, 7))

axes[0].imshow(promotion_wordcloud, interpolation='bilinear')
axes[0].set_title("Promotion Words")
axes[0].axis("off")

axes[1].imshow(non_promotion_wordcloud, interpolation='bilinear')
axes[1].set_title("Non-Promotion Words")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %%
#x_train,x_temp,y_train,y_temp=train_test_split(texts,labels, test_size=0.2, random_state=42,stratify=labels)
#x_test,x_val,y_test,y_val=train_test_split(x_temp,y_temp,test_size=0.5,random_state=42,stratify=y_temp)

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(train_texts)
vocab_size = len(tokenizer.word_index) +1

train_texts_seq = tokenizer.texts_to_sequences(train_texts)
val_texts_seq = tokenizer.texts_to_sequences(val_texts)
test_texts_seq= tokenizer.texts_to_sequences(test_texts)

MAX_LEN = 128
train_texts_padded = pad_sequences(train_texts_seq, maxlen=MAX_LEN, padding='post', truncating='post')
val_texts_padded = pad_sequences(val_texts_seq, maxlen=MAX_LEN, padding='post', truncating='post')
test_texts_padded=pad_sequences(test_texts_seq, maxlen=MAX_LEN, padding='post', truncating='post')

# %%
sentences = [text.split() for text in train_texts]  
word2vec_model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, workers=4)

# %%
embedding_dim = 100  
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, index in tokenizer.word_index.items():
    if word in word2vec_model.wv:
        embedding_matrix[index] = word2vec_model.wv[word]

# %%
model = Sequential([
    Embedding(input_dim=vocab_size,output_dim=embedding_dim,weights=[embedding_matrix], trainable=True),
    
    Conv1D(filters=64, kernel_size=3, activation='relu'),

    BatchNormalization(),

    Conv1D(filters=128, kernel_size=5, activation='relu'),

    GlobalMaxPooling1D(),

    Dense(128, activation='relu'),

    Dropout(0.5),
    
    Dense(64, activation='relu'),

    Dropout(0.5),

    Dense(32, activation='relu'),

    Dropout(0.5),

    Dense(1, activation='sigmoid')

])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5), loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │       1,008,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ ?                           │     0 (unbuilt) │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d                 │ ?                           │     0 (unbuilt) │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,008,500 (3.85 MB)
#  Trainable params: 1,008,500 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels),
    y=train_labels
)
class_weights = dict(enumerate(class_weights))

class_weights
# Out:
# {0: 0.685027541311968, 1: 1.851150202976996}

# %%
history=model.fit(train_texts_padded,train_labels,epochs=100,validation_data=(val_texts_padded,val_labels),batch_size=64,callbacks=[early_stopping],class_weight=class_weights)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 135ms/step - accuracy: 0.5639 - loss: 0.7954 - val_accuracy: 0.5539 - val_loss: 0.6931
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5546 - loss: 0.7855 - val_accuracy: 0.5598 - val_loss: 0.6929
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5524 - loss: 0.7341 - val_accuracy: 0.6181 - val_loss: 0.6925
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5324 - loss: 0.7327 - val_accuracy: 0.6414 - val_loss: 0.6918
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5878 - loss: 0.6925 - val_accuracy: 0.6647 - val_loss: 0.6909
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5512 - loss: 0.7135 - val_accuracy: 0.6910 - val_loss: 0.6897
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5793 - loss: 0.7187 - val_accuracy: 0.7085 - val_loss: 0.6883
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5968 - loss: 0.6889 - val_accuracy: 0.7230 - val_loss: 0.6867
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6209 - loss: 0.6804 - val_accuracy: 0.7259 - val_loss: 0.6851
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6294 - loss: 0.6743 - val_accuracy: 0.7230 - val_loss: 0.6834
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6331 - loss: 0.6620 - val_accuracy: 0.7201 - val_loss: 0.6809
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6349 - loss: 0.6552 - val_accuracy: 0.7289 - val_loss: 0.6771
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6163 - loss: 0.6764 - val_accuracy: 0.7201 - val_loss: 0.6744
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6499 - loss: 0.6438 - val_accuracy: 0.7318 - val_loss: 0.6705
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6633 - loss: 0.6517 - val_accuracy: 0.7522 - val_loss: 0.6645
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6840 - loss: 0.6367 - val_accuracy: 0.7668 - val_loss: 0.6567
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7074 - loss: 0.6347 - val_accuracy: 0.7668 - val_loss: 0.6526
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7109 - loss: 0.6233 - val_accuracy: 0.7901 - val_loss: 0.6438
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7344 - loss: 0.6101 - val_accuracy: 0.7988 - val_loss: 0.6357
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7277 - loss: 0.6101 - val_accuracy: 0.8192 - val_loss: 0.6256
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7601 - loss: 0.5876 - val_accuracy: 0.8222 - val_loss: 0.6153
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7541 - loss: 0.5941 - val_accuracy: 0.8280 - val_loss: 0.6015
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7792 - loss: 0.5654 - val_accuracy: 0.8484 - val_loss: 0.5841
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8022 - loss: 0.5567 - val_accuracy: 0.8601 - val_loss: 0.5681
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8040 - loss: 0.5406 - val_accuracy: 0.8659 - val_loss: 0.5473
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7947 - loss: 0.5437 - val_accuracy: 0.8863 - val_loss: 0.5228
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8244 - loss: 0.5240 - val_accuracy: 0.8892 - val_loss: 0.5006
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8534 - loss: 0.4947 - val_accuracy: 0.8950 - val_loss: 0.4785
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8641 - loss: 0.4599 - val_accuracy: 0.9009 - val_loss: 0.4455
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8652 - loss: 0.4418 - val_accuracy: 0.9096 - val_loss: 0.4145
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8749 - loss: 0.4232 - val_accuracy: 0.9213 - val_loss: 0.3904
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8990 - loss: 0.3965 - val_accuracy: 0.9242 - val_loss: 0.3592
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9170 - loss: 0.3626 - val_accuracy: 0.9300 - val_loss: 0.3311
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9136 - loss: 0.3518 - val_accuracy: 0.9359 - val_loss: 0.3102
# Epoch 35/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9301 - loss: 0.3119 - val_accuracy: 0.9446 - val_loss: 0.2819
# Epoch 36/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9425 - loss: 0.2779 - val_accuracy: 0.9446 - val_loss: 0.2600
# Epoch 37/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9311 - loss: 0.2833 - val_accuracy: 0.9563 - val_loss: 0.2360
# Epoch 38/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.2568 - val_accuracy: 0.9621 - val_loss: 0.2223
# Epoch 39/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9388 - loss: 0.2499 - val_accuracy: 0.9563 - val_loss: 0.2076
# Epoch 40/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9411 - loss: 0.2203 - val_accuracy: 0.9592 - val_loss: 0.1939
# Epoch 41/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9618 - loss: 0.2040 - val_accuracy: 0.9621 - val_loss: 0.1810
# Epoch 42/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9630 - loss: 0.1876 - val_accuracy: 0.9650 - val_loss: 0.1696
# Epoch 43/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9597 - loss: 0.1928 - val_accuracy: 0.9621 - val_loss: 0.1649
# Epoch 44/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9696 - loss: 0.1750 - val_accuracy: 0.9621 - val_loss: 0.1602
# Epoch 45/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9611 - loss: 0.1707 - val_accuracy: 0.9621 - val_loss: 0.1537
# Epoch 46/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9761 - loss: 0.1357 - val_accuracy: 0.9650 - val_loss: 0.1485
# Epoch 47/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9795 - loss: 0.1199 - val_accuracy: 0.9621 - val_loss: 0.1511
# Epoch 48/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.1224 - val_accuracy: 0.9650 - val_loss: 0.1425
# Epoch 49/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9736 - loss: 0.1275 - val_accuracy: 0.9679 - val_loss: 0.1403
# Epoch 50/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9852 - loss: 0.1082 - val_accuracy: 0.9621 - val_loss: 0.1515
# Epoch 51/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9740 - loss: 0.0992 - val_accuracy: 0.9708 - val_loss: 0.1287
# Epoch 52/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9778 - loss: 0.0993 - val_accuracy: 0.9679 - val_loss: 0.1295
# Epoch 53/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9849 - loss: 0.0869 - val_accuracy: 0.9708 - val_loss: 0.1286
# Epoch 54/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9836 - loss: 0.0920 - val_accuracy: 0.9708 - val_loss: 0.1235
# Epoch 55/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9834 - loss: 0.0877 - val_accuracy: 0.9679 - val_loss: 0.1269
# Epoch 56/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9823 - loss: 0.0820 - val_accuracy: 0.9708 - val_loss: 0.1307
# Epoch 57/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9907 - loss: 0.0644 - val_accuracy: 0.9708 - val_loss: 0.1295

# %%
pred=model.predict(test_texts_padded)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step

# %%
from sklearn.metrics import ConfusionMatrixDisplay
pred_labels = (pred > 0.5).astype(int)  

print(f"Accuracy Score: {accuracy_score(test_labels, pred_labels):.4f}")
print(f"Recall Score: {recall_score(test_labels, pred_labels,average='binary'):.4f}")
print(f"Precision Score: {precision_score(test_labels, pred_labels,average='binary'):.4f}")
print(f"F1 Score: {f1_score(test_labels, pred_labels,average='binary'):.4f}")
print(f"Fbeta Score: {fbeta_score(test_labels, pred_labels,beta=0.5,average='binary',pos_label=1):.4f}")

print(f"Classification Report: {classification_report(test_labels, pred_labels)}")

display = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(test_labels, pred_labels))

fig, ax = plt.subplots(figsize=(15,15))
print(f"Confusion Matrix:\n")
display.plot(ax=ax, xticks_rotation='vertical')
# Out:
# Accuracy Score: 0.9708
# Recall Score: 0.9565
# Precision Score: 0.9362
# F1 Score: 0.9462
# Fbeta Score: 0.9402
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       250
#            1       0.94      0.96      0.95        92
#
#     accuracy                           0.97       342
#    macro avg       0.96      0.97      0.96       342
# weighted avg       0.97      0.97      0.97       342
#
# Confusion Matrix:

# %%
def predict_sentiment(text):
    use_text = [preprocess_text(t) for t in text]
    use_text = tokenizer.texts_to_sequences(use_text)
    use_text = pad_sequences(use_text, maxlen=MAX_LEN, padding='post', truncating='post')

    
    pred = model.predict(use_text)
    pred_labels = (pred > 0.5).astype(int)
    pred_labels = pred_labels.flatten() 
    #pred_labels = tf.argmax(pred.logits, axis=1)
    
    label_type = ['NotPromotion', 'Promotion']
    pred_labels = [label_type[i] for i in pred_labels]
    
    for index, pred in enumerate(pred_labels):
        print(f"{text[index]}: {pred}")

# %%
text = [
    "Aku adalah seorang mahasiswa",
    "Judi Online Disebut Masuk Tahap Sosial, Cak Imin: 8,8 Juta Pasien Minta Direhabilitasi Jumat, 15 Nov",
    "Gacor xxtoto menang pasti dibayar",
    "dp jd jt buruan gas garansi meteorwin",
    "gacor pasti menang di xxtoto",
    "top up di kantorbola pasti gampang menangnya",
    "gratis koin buruan topup di agencasinoindonesia",
    "gratis koin buruan topup di fairbet88.com, segera daftarkan akun anda",
    "DEWA-DORA tuh situs yang paling enak withdraw tiap hari! 😖 😣",
    "DEWA-DORA tuh situs yang paling gampang narik tiap hari! 😖 😣",
    "Gua setia maen di DEWADORA, tempat terbaik!",
    "kantorbola99.club - Mau Jackpot x50 x100 x500 x1000 pasti dibayar ? gabung dan Menang berapapun dibayar."
]
predict_sentiment(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# Aku adalah seorang mahasiswa: NotPromotion
# Judi Online Disebut Masuk Tahap Sosial, Cak Imin: 8,8 Juta Pasien Minta Direhabilitasi Jumat, 15 Nov: NotPromotion
# Gacor xxtoto menang pasti dibayar: Promotion
# dp jd jt buruan gas garansi meteorwin: NotPromotion
# gacor pasti menang di xxtoto: Promotion
# top up di kantorbola pasti gampang menangnya: NotPromotion
# gratis koin buruan topup di agencasinoindonesia: NotPromotion
# gratis koin buruan topup di fairbet88.com, segera daftarkan akun anda: Promotion
# DEWA-DORA tuh situs yang paling enak withdraw tiap hari! 😖 😣: Promotion
# DEWA-DORA tuh situs yang paling gampang narik tiap hari! 😖 😣: Promotion
# Gua setia maen di DEWADORA, tempat terbaik!: Promotion
# kantorbola99.club - Mau Jackpot x50 x100 x500 x1000 pasti dibayar ? gabung dan Menang berapapun dibayar.: Promotion
